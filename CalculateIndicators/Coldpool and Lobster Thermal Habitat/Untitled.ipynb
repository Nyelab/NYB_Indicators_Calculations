# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs

# %%
lhf = xr.open_dataset('/Users/nyelab/Downloads/lhtfl.sfc.mon.mean.nc')

# %%
lhf
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 94, lon: 192, nbnds: 2, time: 538)
# Coordinates:
#   * lat        (lat) float32 88.54 86.65 84.75 82.85 ... -84.75 -86.65 -88.54
#   * lon        (lon) float32 0.0 1.875 3.75 5.625 ... 352.5 354.4 356.2 358.1
#   * time       (time) datetime64[ns] 1979-01-01 1979-02-01 ... 2023-10-01
# Dimensions without coordinates: nbnds
# Data variables:
#     time_bnds  (time, nbnds) datetime64[ns] ...
#     lhtfl      (time, lat, lon) float32 ...
# Attributes:
#     Conventions:    CF-1.0
#     title:          Monthly NCEP/DOE Reanalysis 2
#     comments:       Data is from \nNCEP/DOE AMIP-II Reanalysis (Reanalysis-2)...
#     platform:       Model
#     source:         NCEP/DOE AMIP-II Reanalysis (Reanalysis-2) Model
#     institution:    National Centers for Environmental Prediction
#     dataset_title:  NCEP-DOE AMIP-II Reanalysis
#     References:     https://www.psl.noaa.gov/data/gridded/data.ncep.reanalysi...
# ...

# %%
plt.contourf(lhf.lon, lhf.lat,lhf.lhtfl[10,:,:])
plt.colorbar()

# %%
lhf.lat[28]
# Out:
# <xarray.DataArray 'lat' ()>
# array(35.2375, dtype=float32)
# Coordinates:
#     lat      float32 35.24
# Attributes:
#     units:               degrees_north
#     actual_range:        [ 88.542 -88.542]
#     long_name:           Latitude
#     standard_name:       latitude
#     axis:                Y
#     coordinate_defines:  point

# %%
lhf.lon[152]
# Out:
# <xarray.DataArray 'lon' ()>
# array(285., dtype=float32)
# Coordinates:
#     lon      float32 285.0
# Attributes:
#     units:               degrees_east
#     actual_range:        [  0.    358.125]
#     long_name:           Longitude
#     standard_name:       longitude
#     axis:                X
#     coordinate_defines:  point

# %%
-75+360
# Out:
# 285

# %%
plt.plot(lhf.lhtfl[:,28,151])

# %%
plt.contourf(lhf.lon[145:157],lhf.lat[22:32] , lhf.lhtfl[0, 22:32, 145:157])
plt.scatter(lhf.lon[152], lhf.lat[28], color = 'red', s = 20)

# %%
fig,ax = plt.subplots(ncols = 1, nrows = 1, figsize = [20,20],subplot_kw={'projection': ccrs.PlateCarree()})
extent = [280,289.5,28.25,41.5]
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
linewidth=2, color='gray', alpha=0.3, linestyle='--')
gl.xlabels_top = False
gl.ylabels_right = False
gl.xlabels_bottom = True
gl.ylabel_style = {'size': 16, 'color': 'k'}
gl.xlabel_style = {'size': 16, 'color': 'k'}
ax.set_extent(extent)
ax.coastlines(resolution='50m')
CS = ax.contourf(lhf.lon[145:157],lhf.lat[22:32] , lhf.lhtfl[0, 22:32, 145:157],transform=ccrs.PlateCarree(),cmap = 'viridis')
C = ax.scatter(lhf.lon[152], lhf.lat[28], color = 'red', s = 20)
C = ax.scatter(lhf.lon[151], lhf.lat[28], color = 'yellow', s = 20)
#C = ax.contour(glorys.longitude,glorys.latitude,glorys_nyb_bot_t[-6,:,:], levels = [8,10],extend = 'both',transform=ccrs.PlateCarree())
plt.colorbar(CS)

# %%
lhf.lon[151]
# Out:
# <xarray.DataArray 'lon' ()>
# array(283.125, dtype=float32)
# Coordinates:
#     lon      float32 283.1
# Attributes:
#     units:               degrees_east
#     actual_range:        [  0.    358.125]
#     long_name:           Longitude
#     standard_name:       longitude
#     axis:                X
#     coordinate_defines:  point

# %%
360-283.125
# Out:
# 76.875
